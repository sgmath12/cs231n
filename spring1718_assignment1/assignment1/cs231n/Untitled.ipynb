# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure()      # create a figure
plt.plot([1,2,3])
plt.figure()      # create another figure
plt.plot([4,5,6])

# %%
print(2e1)
# Out:
# 20.0
